# %% [markdown]
#  Install python interpreter on your machine.
# https://www.python.org/downloads/windows/

# %% [markdown]
# 1) Assign a Your Full Name to a variable, and then print Greeting message.

# %%
myName = "Yasmine 3laa Mohammed El-Hady"
print("Hi Guys.")
print("I'm", myName, ", have a nice day!")
# Out:
# Hi Guys.
# I'm Yasmine 3laa Mohammed El-Hady , have a nice day!

# %% [markdown]
# 2) Use a variable to represent your favorite number. Then, using that variable, create a message that reveals your favorite number. Print that message

# %%
myFavNum = 4869
message = ("My favourite number is", myFavNum)
print(*message)
# Out:
# My favourite number is 4869

# %% [markdown]
# 3) The volume of a sphere with radius r is 4/3πr3. What is the volume of a sphere
# with radius 5? Start with a variable named radius and then assign the result to
# a variable named volume. Display the result. Add comments to indicate
# that radius is in centimeters and volume in cubic centimeters.

# %%
import math
r = 5 # cm
volume = (4 / 3) * math.pi * (r ** 3) # cm ** 3
print("Volume =", volume)
# Out:
# Volume = 523.5987755982989

# %% [markdown]
# 4. Let’s your program already contains two integer variables, x and y:
# x = 27
# y = 15
# Please complete the program so that it also prints out the following:
# - 27 + 15 = 42
# - 27 - 15 = 12
# - 27 * 15 = 405
# - 27 / 15 = 1.8

# %%
x = 27
y = 15
print(x, "+", y, "=", x + y)
print(x, "-", y, "=", x - y)
print(x, "*", y, "=", x * y)
print(x, "/", y, "=", x / y)
# Out:
# 27 + 15 = 42
# 27 - 15 = 12
# 27 * 15 = 405
# 27 / 15 = 1.8

# %% [markdown]
# 5) Check if a Number is Even or Odd
# Ask the user for a number and determine whether it is even or odd.

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print(num, "is even")
else:
    print(num, "is odd")
# Out:
# 1 is odd

# %% [markdown]
# 6) Find the Largest of Three Numbers
# Take three numbers as input and print the largest one.

# %%
numbers = list(input("Enter 3 numbers: "))
print("Max numbers =", max(numbers))
# Out:
# Max numbers = 4

# %% [markdown]
# 7) Temperature Converter
# Ask the user to enter a temperature in Celsius and convert it to Fahrenheit using the formula
# - **F= (9/5)C + 32**

# %%
C = int(input("Enter a temperture degree in Celsius: "))
F = (9 / 5) * C + 32
print("Tempreture in Fehrenheit =", F)
# Out:
# Tempreture in Fehrenheit = 41.0

# %% [markdown]
# 8) Simple Interest Calculator (SI)
# Given principal(P), rate(R), and time(T), calculate the simple interest using **SI = (P * R * T) / 100**

# %%
P = 6
R = 7
T = 8
SI = (P * R * T) / 100
print("Simple Interest (SI) =", SI)
# Out:
# Simple Interest (SI) = 3.36

# %% [markdown]
#  9) Please write a program which asks the user for a number of days. The program
# then prints out the number of seconds in the number of days given.
# - How many days? 1
# - Seconds in that many days: 86400

# %%
days = int(input("How many days?"))
hours = 24 * days
minutes = 60 * hours
seconds = 60 * minutes
print("Seconds in", days, ":", seconds)
# Out:
# Seconds in 1 : 86400
